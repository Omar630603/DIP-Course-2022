# %% [markdown]
# <a href="https://colab.research.google.com/github/Omar630603/DIP-Course-2022/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Connect Google Drive Files

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import Libraries

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/DIP/Images/kitten01.jpg')
plt.imshow(img)

# %% [markdown]
# # Channel BGR (Blue Green Red) Display pixel value and image

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %% [markdown]
# # Grayscale image, resizing, flipping, saving the resulted image

# %%
img_gray = cv.imread('/content/drive/MyDrive/DIP/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# # Creating 2D Geometry image

# %%
black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200, 200), pt2=(300, 300), color=(0, 0 , 255), thickness=15)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(384, 0), pt2=(510, 150), color=(0, 255 , 0), thickness=10)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100, 100), radius=50, color=(255, 0 , 0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0, 0), pt2=(512, 512), color=(255, 255 , 255), thickness=5)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(400, 400), radius=50, color=(255, 0 , 0), thickness=2)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello, Omar!', org=(10, 500), fontFace=font, fontScale=2, color=(255,255,0), thickness=1, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512, 512, 3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100, 300], [200, 200], [400, 300], [200, 400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1, 1, 2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255, 0, 0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # Task

# %%
image = cv.imread('/content/drive/MyDrive/DIP/Images/jungle.png')
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
plt.imshow(image)

# %%
imageFig = plt.figure(figsize=(10, 10))
imageAx = imageFig.add_subplot(111)
imageAx.imshow(image)

pixelSize1 = image.shape[0] * image.shape[1]
print('image pixel size = ', image.shape[0],' * ', image.shape[1], ' = ', pixelSize1)
# Out:
# image pixel size =  436  *  772  =  336592

# %% [markdown]
# # Red and Green Channels

# %%
imageRedGreen = cv.cvtColor(image, cv.COLOR_BGR2RGB)
imageRedGreen[:,:,2] = 0
plt.imshow(imageRedGreen)

# %% [markdown]
# # Green and Blue channels

# %%
imageGreenBlue = cv.cvtColor(image, cv.COLOR_BGR2RGB)
imageGreenBlue[:,:,0] = 0
plt.imshow(imageGreenBlue)

# %% [markdown]
# # Row 10-100, column 10-100

# %%
imageZoomed = cv.imread('/content/drive/MyDrive/DIP/Images/jungle.png')
imageZoomed = cv.cvtColor(imageZoomed, cv.COLOR_BGR2RGB)
plt.imshow(imageZoomed[10:100, 10:100])

# %%
imageZoomed1 = cv.imread('/content/drive/MyDrive/DIP/Images/jungle.png')
imageZoomed1 = cv.cvtColor(imageZoomed1, cv.COLOR_BGR2RGB)
plt.imshow(imageZoomed[5:30])

# %% [markdown]
# # Random boxes

# %%
imageRandom = cv.imread('/content/drive/MyDrive/DIP/Images/jungle.png')
imageRandom = cv.cvtColor(imageRandom, cv.COLOR_BGR2RGB)
cv.rectangle(imageRandom, pt1=(100, 20), pt2=(200, 300), color=(0, 255 , 0), thickness=10)
cv.rectangle(imageRandom, pt1=(35, 100), pt2=(255, 254), color=(255, 255 , 0), thickness=15)
cv.rectangle(imageRandom, pt1=(23, 11), pt2=(150, 10), color=(0, 255 , 255), thickness=13)
cv.rectangle(imageRandom, pt1=(25, 70), pt2=(220, 52), color=(255, 0 , 0), thickness=12)
cv.rectangle(imageRandom, pt1=(95, 10), pt2=(30, 22), color=(0, 0 , 255), thickness=16)
plt.imshow(imageRandom)

# %% [markdown]
# # Upsidedown image

# %%
imageUpDown = cv.flip(cv.cvtColor(imageRandom, cv.COLOR_BGR2RGB), 0)
plt.imshow(imageUpDown)

# %% [markdown]
# # Rectangles and circles on the face of my photo

# %%
imageOmar = cv.imread('/content/drive/MyDrive/DIP/Images/omar.png')
imageOmar = cv.cvtColor(imageOmar, cv.COLOR_BGR2RGB)
plt.imshow(imageOmar)

# %%
cv.rectangle(imageOmar, pt1=(300, 100), pt2=(600, 450), color=(0, 255 , 0), thickness=10)
cv.circle(imageOmar, center=(400, 300), radius=100, color=(255, 0 , 0), thickness=10)
plt.imshow(imageOmar)

# %%
imageCat = cv.imread('/content/drive/MyDrive/DIP/Images/kitten01.jpg')
imageCat = cv.cvtColor(imageCat, cv.COLOR_BGR2RGB)
imageCat[:,:,0] = 0
imageCat[:,:,1] = 0
cv.rectangle(imageCat, pt1=(0, 500), pt2=(100, imageCat.shape[0]), color=(0, 255 , 0), thickness=10)
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(imageCat, text='Omar', org=(10, 100), fontFace=font, fontScale=3, color=(255,255,255), thickness=2, lineType=cv.LINE_AA)
plt.imshow(imageCat)
