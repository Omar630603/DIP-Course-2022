# %% [markdown]
# <a href="https://colab.research.google.com/github/Omar630603/DIP-Course-2022/blob/main/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import PIL
import io
import html
import time
# %matplotlib inline
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode

# %%
cascade_face = cv.CascadeClassifier('/content/drive/MyDrive/DIP/Images/haarcascades/haarcascade_frontalface_alt.xml')

# JOKOWI
jokowi = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/jokowi.jpg')
jokowi1 = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/jokowi.jpg')
roi_face1 = cascade_face.detectMultiScale(jokowi1) 

roi_face = cascade_face.detectMultiScale(jokowi) 
for(x,y,w,h) in roi_face: 
 cv.rectangle(jokowi,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(jokowi1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(jokowi1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(jokowi, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(jokowi, cv.COLOR_BGR2RGB))
plt.show()

#RA.Kartini
kartini = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/kartini.jpg')
kartini1 = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/kartini.jpg')
roi_face1 = cascade_face.detectMultiScale(kartini1) 

roi_face = cascade_face.detectMultiScale(kartini) 
for(x,y,w,h) in roi_face: 
 cv.rectangle(kartini,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(kartini1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(kartini1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(kartini, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(kartini, cv.COLOR_BGR2RGB))
plt.show()

#MEONG
meong = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/kucing.jpg')
meong1 = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/kucing.jpg')

meong_original = cv.cvtColor(meong, cv.COLOR_BGR2RGB)
meong_second = cv.cvtColor(meong1, cv.COLOR_BGR2RGB)


roi_face = cascade_face.detectMultiScale(meong_second)
for (x,y,w,h) in roi_face: 
  cv.rectangle(meong_second,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(meong_original, cmap='gray')
plt.subplot(122),plt.imshow(meong_second, cmap='gray')
plt.show()

#MASKED WOMAN
mask = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/mask.png')
mask1 = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/mask.png')

mask_original = cv.cvtColor(mask, cv.COLOR_BGR2RGB)
mask1_second = cv.cvtColor(mask1, cv.COLOR_BGR2RGB)

roi_face = cascade_face.detectMultiScale(mask1_second)
for(x,y,w,h) in roi_face:
 cv.rectangle(mask1_second,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(mask_original)
plt.subplot(122),plt.imshow(mask1_second)
plt.show() 

#JORDAN
jordan = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/mjordan.jpg')
jordan1 = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/mjordan.jpg')

jordan_original = cv.cvtColor(jordan, cv.COLOR_BGR2RGB)
jordan1_second = cv.cvtColor(jordan1, cv.COLOR_BGR2RGB)


roi_face = cascade_face.detectMultiScale(jordan1_second)
for(x,y,w,h) in roi_face:
 cv.rectangle(jordan1_second,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(jordan_original)
plt.subplot(122),plt.imshow(jordan1_second)
plt.show()

#GROUP OF PEOPLE
group_photo = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/solvayconf.jpg')
group_photo1 = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/solvayconf.jpg')

group_photo_original = cv.cvtColor(group_photo, cv.COLOR_BGR2RGB)
group_photo1_second = cv.cvtColor(group_photo1, cv.COLOR_BGR2RGB)

roi_face = cascade_face.detectMultiScale(group_photo1_second)
for(x,y,w,h) in roi_face:
 cv.rectangle(group_photo1_second,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(group_photo_original)
plt.subplot(122),plt.imshow(group_photo1_second)
plt.show()

# %%
cascade_face = cv.CascadeClassifier('/content/drive/MyDrive/DIP/Images/haarcascades/haarcascade_frontalcatface.xml')

cat = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/kucing.jpg')
cat1 = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/kucing.jpg')

cat_original = cv.cvtColor(cat, cv.COLOR_BGR2RGB)
cat1_second = cv.cvtColor(cat1, cv.COLOR_BGR2RGB)

roi_wajah = cascade_face.detectMultiScale(cat1_second)
for (x,y,w,h) in roi_wajah: 
  cv.rectangle(cat1_second,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cat_original)
plt.subplot(122),plt.imshow(cat1_second)
plt.show()

# %%
cascade_face = cv.CascadeClassifier('/content/drive/MyDrive/DIP/Images/haarcascades/haarcascade_lefteye_2splits.xml') 

jokowi = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/jokowi.jpg')
jokowi1 = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/jokowi.jpg')

jokowi_original = cv.cvtColor(jokowi, cv.COLOR_BGR2RGB)
jokowi1_second = cv.cvtColor(jokowi1, cv.COLOR_BGR2RGB)

roi_face = cascade_face.detectMultiScale(jokowi1_second)
for (x,y,w,h) in roi_wajah: 
  cv.rectangle(jokowi1_second,(x,y),(x+w,y+h),(0,255,0),3)

f, axarr = plt. subplots(1,2,figsize=(15,15))
plt.subplot(121),plt.imshow(jokowi_original)
plt.subplot(122),plt.imshow(jokowi1_second)
plt.show()

# %%
def js_to_image(js_reply):
  image_bytes = b64decode(js_reply.split(',')[1])
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  img = cv.imdecode(jpg_as_np, flags=1)

  return img


def bbox_to_bytes(bbox_array):
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  bbox_PIL.save(iobuf, format='png')
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64decode(iobuf.getvalue()), 'utf-8')))
  
  return bbox_to_bytes

face_cascade = cv.CascadeClassifier('/content/drive/MyDrive/DIP/Images/haarcascades/haarcascade_frontalface_default.xml')

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality){
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)

  data = eval_js('takePhoto({})'.format(quality))
  img = js_to_image(data)
  gray = cv.cvtColor(img, cv.COLOR_RGB2GRAY)
  print(gray.shape)
  faces = face_cascade.detectMultiScale(gray)
  for(x,y,w,h) in faces:
    img = cv.rectangle(img,(x,y),(x+w,y+h),(0, 255, 0),2)

  cv.imwrite(filename, img)

  return filename

try:
  filename = take_photo('photo.jpg')
  print('Saved to {}'.format(filename))

  display(Image(filename))
except Exception as err:
  print(str(err))
# Out:
# (480, 640)
# Saved to photo.jpg

# %%
cascade_face = cv.CascadeClassifier('/content/drive/MyDrive/DIP/Images/haarcascades/haarcascade_frontalface_alt.xml')

image = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/mjordan.jpg') 
image1 = cv.imread('/content/drive/MyDrive/DIP/Images/facedet/mjordan.jpg') 
image = cv.cvtColor(image, cv.COLOR_BGR2RGB) 
image1 = cv.cvtColor(image1, cv.COLOR_BGR2RGB) 
figure_size = 9 


jorden_face = cascade_face.detectMultiScale(image1) 
for(x,y,w,h) in jorden_face: 
#  cv.rectangle(image1,(x,y),(x+w,y+h),(0,255,0),3)
 roi = image1[y:y+h, x:x+w]
 roi = cv.GaussianBlur(roi, (23, 23), 30)
 image1[y:y+roi.shape[0], x:x+roi.shape[1]] = roi 

f, axarr = plt. subplots(1,2,figsize=(15,15))
plt.subplot(121), plt.imshow(image),plt.title('Original')
plt.subplot(122), plt.imshow(image1),plt.title('Median Filter')
plt.show()
